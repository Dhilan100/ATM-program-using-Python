# %%
## Loading
print("Welcome to Dhilan's ATM")
from time import sleep
sleep(0.5)

print("\nDev Mode intiated. Balance = £9. PIN: 1234")
sleep(0.5)

print("")
sleep(0.5)

print("Loading ATM")
print ("", end ="\n")
sleep(1)

print("ATM SERVICES:")
print("")
sleep(0.5)

#loading dots
for i in range (1,6):
    sleep(0.3)
    print(".", end ="")
    i=i+1
#INSERT CARD#
print ("")
sleep(0.7)

print("\nPlease insert bank card!")

#Dev overirde for testing purposes#
print ("")
sleep(0.5)
print("Dev Mode: Card insert overrided")

#next line   
print("")
sleep(0.5)




#Pin system
password = "1234"
pin = input("Please input 4 digit PIN: ")

if pin == password:
    print("", end ="\n")
    for i in range (1,6):
        sleep(0.3)
        print(".", end ="")
        i=i+1
    print("")
    print("\nPin is correct!")
else:
    while pin != password or not pin.isdigit():
        print("", end ="\n")
        for i in range (1,6):
            sleep(0.3)
            print(".", end ="")
            i=i+1
        print("")
        print("\nError 1: You have entered incorrectly. Please try again")
        sleep(0.5)
        pin = input("\nPlease input 4 digit PIN: ")
        

print ("", end ="\n")
for i in range (1,6):
    sleep(0.3)
    print(".", end ="")
    i=i+1
    
print ("", end ="\n")
sleep(0.5)

balance = 9
enter = 0
while enter !="4":
    print ("\n---ATM MENU---\n") # title of the ATM
    sleep(0.5)
    print ("[1] Bank Balance |", "[2] Deposit\n") #menu options#
    sleep(0.5)
    print ("[3] Withdraw |", "[4] Close\n")
    sleep(0.5)
    enter = input("Please enter the menu number to continue: \n") #user input for menu#
    if enter == "1":
        print ("", end ="\n")#dot effect#
        for i in range (1,6):
            sleep(0.3)
            print(".", end ="")
            i=i+1
        print("")
        print(f"\nYour balance is £{balance}.") #balance is shown
        sleep(1)                    
        print("\nWhat else would you like to do?") 
        sleep(1) #this loop then returns to the menu
        
    elif enter == "2":
        print ("", end ="\n")
        for i in range (1,6):
            sleep(0.3)
            print(".", end ="")
            i=i+1
        deposit = input("\nPlease enter amount in £ to deposit (in integars): \n£")
        if  not deposit.isdigit:
            print("\nError 6: You have entered incorrectly. Please try again")
                       
        else:
            deposit_int = int(deposit)
            if int(deposit) >= 0:
                balance = balance + deposit_int
                sleep(1)
                print ("")#dot effect#
                for i in range (1,6):
                    sleep(0.3)
                    print(".", end ="")
                    i=i+1
                print("")
                print(f"\nYour new balance is £{balance}.")
            else:
                print("\nError 7: You have entered a value less than 0. Please try again.")
            sleep(1)
            print("\nWhat else would you like to do?") 
            print ("", end ="")
        for i in range (1,6):
            sleep(0.3)
            print(".", end ="")
            i=i+1
        print("")
            
    elif enter == "3":
        withdraw = 0
        while withdraw !=6:
            sleep(0.5)
            print("")
            print("Amount to Withdraw: ")
            sleep(0.5)
            print("[1] £10", "[2] £20")
            sleep(0.5)
            print("[3] £50", "[4] £100")
            sleep(0.5)
            print("[5] Custom Amount", "[6] Go back to Main Menu")
            withdraw = input("Please enter the option number to continue: \n")
            if withdraw == "1":
                sleep(1)
                print("")
                print("You have selected £10, ATM is withdrawing, please wait a moment")
                print("")
                for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                print("")
                if balance >= 10: #checks to see if 10 or more is available to withdraw
                    sleep(0.5)
                    print("Please take the money dispensed.")
                    balance = balance - 10
                    sleep(0.5)
                    print(f"Your balance is now £{balance}")
                    sleep(1)                    
                    print("\nWhat else would you like to do?") 
                    print ("", end ="\n")
                    for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                    print("")#this loop returns to Amount menu# 
                    
                else:
                    sleep(1)
                    print("")
                    print("You have less than £10 in your account, please deposit money into the bank!")
                    print(f"Your current balance: £{balance}")
                    sleep(1)                    
                    print("\nWhat else would you like to do?") 
                    print ("", end ="\n")
                    for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                    print("")#this loop returns to Amount menu# 
                    
            elif withdraw == "2":
                sleep(1)
                print("")
                print("You have selected £20, ATM is withdrawing, please wait a moment")
                print("")
                for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                print("")
                if balance >= 20: #checks to see if 20 or more is available to withdraw
                    sleep(0.5)
                    print("Please take the money dispensed.")
                    balance = balance - 20
                    sleep(0.5)
                    print(f"Your balance is now £{balance}")
                    sleep(1)                    
                    print("\nWhat else would you like to do?") 
                    print ("", end ="\n")
                    for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                    print("")#this loop returns to Amount menu#
                    
                else:
                    sleep(1)
                    print("")
                    print("You have less than £20 in your account, please deposit money into the bank!")
                    print(f"Your current balance: £{balance}")
                    sleep(1)                    
                    print("\nWhat else would you like to do?") 
                    print ("", end ="\n")
                    for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                    print("")#this loop returns to Amount menu# 
                    
            elif withdraw == "3":
                sleep(1)
                print("")
                print("You have selected £50, ATM is withdrawing, please wait a moment")
                print("")
                for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                print("")
                if balance >= 50: #checks to see if 50 or more is available to withdraw
                    sleep(0.5)
                    print("Please take the money dispensed.")
                    balance = balance - 50
                    sleep(0.5)
                    print(f"Your balance is now £{balance}")
                    sleep(1)                    
                    print("What else would you like to do?")
                    sleep(1) #this loop returns to Amount menu#
                    
                else:
                    sleep(1)
                    print("")
                    print("You have less than £50 in your account, please deposit money into the bank!")
                    print(f"Your current balance: £{balance}")
                    sleep(1)                    
                    print("\nWhat else would you like to do?") 
                    print ("", end ="\n")
                    for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                    print("")#this loop returns to Amount menu#
                    
            elif withdraw == "4":
                sleep(1)
                print("")
                print("You have selected £100, ATM is withdrawing, please wait a moment")
                print("")
                for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                print("")
                if balance >= 100: #checks to see if 100 or more is available to withdraw
                    sleep(1)
                    print("Please take the money dispensed.")
                    balance = balance - 100
                    sleep(0.5)
                    print(f"Your balance is now £{balance}")
                    sleep(1)        
                    print("\nWhat else would you like to do?") 
                    print ("", end ="\n")
                    for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                    print("")#this loop returns to Amount menu# 
                    
                else:
                    sleep(1)
                    print("")
                    print("You have less than £100 in your account, please deposit money into the bank!")
                    print(f"Your current balance: £{balance}")
                    sleep(1)                    
                    print("\nWhat else would you like to do?") 
                    print ("", end ="\n")
                    for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                    print("")#this loop returns to Amount menu# 
                    
            elif withdraw == "5":
                sleep(0.5)
                w = input("Please enter the amount in £ you wish to withdraw (in multiples of 10): \n£")
                print("")
                sleep(1)
                print(f"ATM is trying to withdraw {w}, please wait a moment")
                print("")
                for i in range (1,6): #dot effect#
                        sleep(0.3)
                        print(".", end ="")
                        i=i+1
                print("")
                if not w.isdigit():
                    sleep(1)
                    print("\nError 8: You have entered incorrectly. Please try again")
                    
                else:
                    withdraw_int = int(w)    
                    if withdraw_int%10 == 0:
                        if balance >= withdraw_int:
                            balance = balance - withdraw_int
                            sleep(1)
                            print("Please take the money dispensed.\n")
                            print(f"Your new balance is £{balance}")
                            sleep(0.5)
                            print("\nWhat else would you like to do?") 
                            print ("", end ="\n")
                            for i in range (1,6):#dot effect#
                                sleep(0.3)
                                print(".", end ="")
                                i=i+1
                            print("")#this loop returns to Amount menu# 
                        
                        else:
                            sleep(1)
                            print("")
                            print(f"You have less than £{withdraw_int}, please deposit money into the bank!")
                            print(f"Your current balance: £{balance}")
                            sleep(1)                    
                            print("\nWhat else would you like to do?") 
                            print ("", end ="\n")
                            for i in range (1,6):
                                sleep(0.3)
                                print(".", end ="")
                                i=i+1
                            print("")#this loop returns to Amount menu#    
                    else:
                        sleep(0.5)
                        print("Please enter an amount in multples of 10!")
                        sleep(1)                    
                        print("\nWhat else would you like to do?") 
                        print ("", end ="\n")
                        for i in range (1,6):
                            sleep(0.3)
                            print(".", end ="")
                            i=i+1
                        print("") #this loop returns to Amount menu#
                    
            elif withdraw == "6":
                sleep(0.5)
                break #stops the loop and goes back to the main menu~
                
            elif withdraw != "1" and withdraw != "2" and withdraw != "3" and withdraw != "4" and withdraw != "5" and withdraw != "6":
                print("\nError 4: You have entered incorrectly. Please try again")
        else:
            print("\nError 5: You have entered incorrectly. Please try again\n")
             
    elif enter == "4": #exits the ATM#
        print("")
        for i in range (1,6):
            sleep(0.3)
            print(".", end ="")
            i=i+1
        print("")
        print("\nThank you for using ATM Services and have a great day!")#end message#
        break
        
    elif enter !="1" and enter!="2" and enter!= "3" and enter!="4":
        print("\nError 3: You have entered incorrectly. Please try again")
        
    else:
        print("\nError 2: You have entered incorrectly. Please try again")
# Out:
# Welcome to Dhilan's ATM
#
# Dev Mode intiated. Balance = £9. PIN: 1234
#
# Loading ATM
#
# ATM SERVICES:
#
# .....
#
# Please insert bank card!
#
# Dev Mode: Card insert overrided
# Please input 4 digit PIN:  1234
# .....
#
# Pin is correct!
#
# .....
#
# ---ATM MENU---
#
# [1] Bank Balance | [2] Deposit
#
# [3] Withdraw | [4] Close
# Please enter the menu number to continue:
#  2
# .....
# Please enter amount in £ to deposit (in integars):
# £ 5
# .....
#
# Your new balance is £14.
#
# What else would you like to do?
# .....
#
# ---ATM MENU---
#
# [1] Bank Balance | [2] Deposit
#
# [3] Withdraw | [4] Close
# Please enter the menu number to continue:
#  4
# .....
#
# Thank you for using ATM Services and have a great day!
